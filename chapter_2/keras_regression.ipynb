# %% [markdown]
# # **COURSE: INTRODUCTION TO DEEP LEARNING USING KERAS - PEER GRADED ASSIGNMENT**
#
# **AUTHOR:** DO HUU KIET
#
# ### **1. Assignment Topic:**
#
# In this project, you will build a regression model using the Keras library to model the same data about concrete compressive strength that we used in labs 3.
#
# ### **2. Concrete Data:**
#
# For your convenience, the data can be found here again: https://cocl.us/concrete_data. To recap, the predictors in the data of concrete strength include:
#
# - Cement
# - Blast Furnace Slag
# - Fly Ash
# - Water
# - Superplasticizer
# - Coarse Aggregate
# - Fine Aggregate
#
# ### **3. Assignment Instructions:**
#
# Please check the My Submission tab for detailed assignment instructions.
#
# ### **4. How to submit:**
#
# You will need to submit your code for each part in a Jupyter Notebook. Since each part builds on the previous one, you can submit the same notebook four times for grading. Please make sure that you:
#
# - Use Markdown to clearly label your code for each part,
# - Properly comment your code so that your peer who is grading your work is able to understand your code easily,
# - Include your comments and discussion of the difference in the mean of the mean squared errors among the different parts.

# %%
# Import dependencies
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
import pandas as pd
import numpy as np

# %% [markdown]
# ## **A. Build a baseline model (5 marks)**
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# **1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the `train_test_split` helper function from Scikit-learn.**
#
# **2. Train the model on the training data using 50 epochs.**
#
# **3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.**
#
# **4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.**
#
# **5. Report the mean and the standard deviation of the mean squared errors.**

# %%
# Building the model
def build_model():
    model = Sequential()
    # One hidden layer with 10 neurons and relu activation function
    model.add(Dense(10, activation='relu', input_shape=(8, )))
    # Output layer with 1 neuron and linear activation function
    model.add(Dense(1, activation='linear'))
    # Define the optimizer
    optimizer = Adam(learning_rate=0.001)
    # Compile the model
    model.compile(optimizer=optimizer, loss='mse')
    
    return model

model = build_model()

model.summary()
# Out:
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 10)             │            90 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101 (404.00 B)
#  Trainable params: 101 (404.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Load the concrete data
concrete_data = pd.read_csv("https://cocl.us/concrete_data")

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %%
# Split the data into predictors and target
X = concrete_data.drop('Strength', axis=1)
y = concrete_data['Strength']
print(X.head())
print(f"X shape: {X.shape}\n\n")
print(y.head())
print(f"y shape: {y.shape}")
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360
# X shape: (1030, 8)
#
#
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64
# y shape: (1030,)

# %%
# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (721, 8) (309, 8) (721,) (309,)

# %%
# Train the model
model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 14813.4629 - val_loss: 6300.1675
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4974.9868 - val_loss: 1588.1301
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1319.0139 - val_loss: 538.7869
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 465.1263 - val_loss: 500.3997
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 436.1891 - val_loss: 478.3016
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 391.3938 - val_loss: 434.7843
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 394.7749 - val_loss: 415.0136
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 341.6501 - val_loss: 401.6058
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 378.4477 - val_loss: 391.2364
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 349.4711 - val_loss: 381.1963
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 356.8975 - val_loss: 373.3109
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 343.8655 - val_loss: 366.1903
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 318.3631 - val_loss: 366.8184
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 339.1940 - val_loss: 357.7113
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 320.2222 - val_loss: 358.3388
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 304.9679 - val_loss: 351.8956
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 317.7259 - val_loss: 349.7658
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 331.0444 - val_loss: 345.7672
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 315.3410 - val_loss: 343.0729
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 301.1473 - val_loss: 334.9913
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 317.4026 - val_loss: 337.6636
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 296.7721 - val_loss: 336.7850
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 299.7116 - val_loss: 323.9865
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 294.4611 - val_loss: 322.7807
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 263.1099 - val_loss: 321.3762
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 263.8495 - val_loss: 319.8565
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 273.5011 - val_loss: 313.7205
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 280.6378 - val_loss: 315.5568
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 262.8278 - val_loss: 307.3115
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 281.2037 - val_loss: 306.0994
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 247.4155 - val_loss: 305.4782
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 235.6060 - val_loss: 294.8960
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 263.2011 - val_loss: 295.6701
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 257.6220 - val_loss: 295.9064
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 253.1902 - val_loss: 281.6762
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 230.3099 - val_loss: 282.7335
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 241.2870 - val_loss: 280.4680
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 241.3918 - val_loss: 278.0840
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 224.6333 - val_loss: 273.2014
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 208.4657 - val_loss: 264.9893
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 255.9933 - val_loss: 267.2757
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 213.2234 - val_loss: 264.0161
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 223.9704 - val_loss: 258.8488
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 204.1060 - val_loss: 261.3529
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 220.9425 - val_loss: 253.9988
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 236.2989 - val_loss: 252.9136
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 211.8096 - val_loss: 245.5486
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 233.0629 - val_loss: 253.0168
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 205.8862 - val_loss: 248.0251
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 218.7804 - val_loss: 235.3610

# %%
# Get Mean squared error
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Mean Squared Error: 212.4226777377792

# %%
# Rebuild model
model = build_model()

# Create MSE list
mse_list = []

# Repeat 50 times
for i in range(50):
    print(f"Running iteration {i+1}")
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=0)
    y_pred = model.predict(X_test)
    loss = mean_squared_error(y_test, y_pred)
    mse_list.append(loss)
    print(f"Loss: {loss:.2f}")

# List length
print(f"List length: {len(mse_list)}")

# Print the mean and standard deviation of the MSE list
print(f"Mean: {sum(mse_list)/len(mse_list):.2f}")
print(f"Standard Deviation: {np.std(mse_list):.2f}")
# Out:
# Running iteration 1
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Loss: 152.18
# Running iteration 2
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 116.21
# Running iteration 3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 119.92
# Running iteration 4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 101.93
# Running iteration 5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 105.21
# Running iteration 6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 114.11
# Running iteration 7
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 106.36
# Running iteration 8
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 109.18
# Running iteration 9
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 106.13
# Running iteration 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 119.39
# Running iteration 11
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 125.84
# Running iteration 12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 108.52
# Running iteration 13
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 120.62
# Running iteration 14
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 117.21
# Running iteration 15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 114.26
# Running iteration 16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 104.60
# Running iteration 17
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 115.21
# Running iteration 18
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 100.83
# Running iteration 19
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 84.98
# Running iteration 20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 73.32
# Running iteration 21
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 68.69
# Running iteration 22
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 58.16
# Running iteration 23
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.25
# Running iteration 24
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 54.12
# Running iteration 25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 51.07
# Running iteration 26
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 48.00
# Running iteration 27
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.77
# Running iteration 28
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 53.08
# Running iteration 29
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 53.63
# Running iteration 30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.14
# Running iteration 31
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 48.56
# Running iteration 32
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 51.26
# Running iteration 33
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 54.32
# Running iteration 34
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 54.17
# Running iteration 35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 55.95
# Running iteration 36
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 50.86
# Running iteration 37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 51.30
# Running iteration 38
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 45.11
# Running iteration 39
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 58.04
# Running iteration 40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 48.51
# Running iteration 41
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 49.93
# Running iteration 42
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 52.33
# Running iteration 43
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 49.15
# Running iteration 44
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 54.88
# Running iteration 45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 48.80
# Running iteration 46
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 50.85
# Running iteration 47
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 52.72
# Running iteration 48
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 56.83
# Running iteration 49
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.29
# Running iteration 50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 50.56
# List length: 50
# Mean: 75.45
# Standard Deviation: 30.66

# %% [markdown]
# The mean of mean squared error after 50 iterations of 50 epoch/iterations is 56.91
#
# The standard deviation of the mean of mean squared error list is 21.59

# %% [markdown]
# ## **B. Normalize the data (5 marks)**
#
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %%
# Normalize the data
X_norm = (X - X.mean()) / X.std()
y_norm = (y - y.mean()) / y.std()
print(X_norm.head())
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %%
# Split the data into training and testing data
X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (721, 8) (309, 8) (721,) (309,)

# %%
# Train the model
model = build_model()

model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=1)
# Out:
# Epoch 1/50
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1446.5547 - val_loss: 1575.1530
# Epoch 2/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1431.0178 - val_loss: 1562.6393
# Epoch 3/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1417.1797 - val_loss: 1550.1039
# Epoch 4/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1340.9275 - val_loss: 1537.3656
# Epoch 5/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1385.1401 - val_loss: 1524.5216
# Epoch 6/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1463.0737 - val_loss: 1510.8451
# Epoch 7/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1372.2156 - val_loss: 1497.4159
# Epoch 8/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1430.2620 - val_loss: 1483.0608
# Epoch 9/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1465.7384 - val_loss: 1468.6010
# Epoch 10/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1389.4390 - val_loss: 1453.8877
# Epoch 11/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1329.8148 - val_loss: 1438.6011
# Epoch 12/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1401.6953 - val_loss: 1422.4109
# Epoch 13/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1361.6100 - val_loss: 1405.9504
# Epoch 14/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1274.9580 - val_loss: 1389.0667
# Epoch 15/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1290.7563 - val_loss: 1371.5627
# Epoch 16/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1312.3281 - val_loss: 1353.3997
# Epoch 17/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1245.7524 - val_loss: 1334.4229
# Epoch 18/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1269.2499 - val_loss: 1315.1608
# Epoch 19/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1288.1007 - val_loss: 1295.5615
# Epoch 20/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1131.2930 - val_loss: 1275.8519
# Epoch 21/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1109.5077 - val_loss: 1255.0280
# Epoch 22/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1152.3392 - val_loss: 1234.1086
# Epoch 23/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1108.9495 - val_loss: 1212.7650
# Epoch 24/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1108.6946 - val_loss: 1191.1263
# Epoch 25/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1090.4474 - val_loss: 1169.6869
# Epoch 26/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1111.5103 - val_loss: 1147.6952
# Epoch 27/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1004.6152 - val_loss: 1125.8268
# Epoch 28/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1063.5609 - val_loss: 1103.8541
# Epoch 29/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1000.2983 - val_loss: 1081.3329
# Epoch 30/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 997.2524 - val_loss: 1059.0483
# Epoch 31/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 964.2184 - val_loss: 1036.7366
# Epoch 32/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 914.3765 - val_loss: 1014.3632
# Epoch 33/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 930.7140 - val_loss: 992.0210
# Epoch 34/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 854.8411 - val_loss: 969.5187
# Epoch 35/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 880.5139 - val_loss: 947.6273
# Epoch 36/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 857.0687 - val_loss: 925.4303
# Epoch 37/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 815.1528 - val_loss: 904.0051
# Epoch 38/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 801.2953 - val_loss: 882.2767
# Epoch 39/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 814.6328 - val_loss: 861.0661
# Epoch 40/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 801.2079 - val_loss: 840.0625
# Epoch 41/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 792.3655 - val_loss: 818.9795
# Epoch 42/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 754.2734 - val_loss: 798.2827
# Epoch 43/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 714.0422 - val_loss: 778.5349
# Epoch 44/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 728.0732 - val_loss: 758.6037
# Epoch 45/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 724.2590 - val_loss: 738.6431
# Epoch 46/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 677.3693 - val_loss: 719.3857
# Epoch 47/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 632.9688 - val_loss: 700.3478
# Epoch 48/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 641.0655 - val_loss: 681.6147
# Epoch 49/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 643.4583 - val_loss: 663.0560
# Epoch 50/50
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 593.6621 - val_loss: 644.5253

# %%
# Get Mean squared error
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f"Mean Squared Error: {mse}")
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Mean Squared Error: 663.1532586521622

# %%
# Rebuild model
model = build_model()

# Create MSE list
mse_list_norm = []

# Repeat 50 times
for i in range(50):
    print(f"Running iteration {i+1}")
    X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3)
    model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=0)
    y_pred = model.predict(X_test)
    loss = mean_squared_error(y_test, y_pred)
    mse_list_norm.append(loss)
    print(f"Loss: {loss:.2f}")

# List length
print(f"List length: {len(mse_list_norm)}")

# Print the mean and standard deviation of the MSE list
print(f"Mean: {sum(mse_list_norm)/len(mse_list_norm):.2f}")
print(f"Standard Deviation: {np.std(mse_list_norm):.2f}")
# Out:
# Running iteration 1
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Loss: 491.85
# Running iteration 2
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 181.91
# Running iteration 3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 141.80
# Running iteration 4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 144.67
# Running iteration 5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 128.68
# Running iteration 6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 94.01
# Running iteration 7
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 77.87
# Running iteration 8
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 71.73
# Running iteration 9
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 71.76
# Running iteration 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 65.45
# Running iteration 11
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 53.59
# Running iteration 12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 49.33
# Running iteration 13
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 50.87
# Running iteration 14
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 42.72
# Running iteration 15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 45.80
# Running iteration 16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 44.99
# Running iteration 17
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 46.94
# Running iteration 18
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 41.37
# Running iteration 19
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 41.01
# Running iteration 20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 41.93
# Running iteration 21
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.96
# Running iteration 22
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 46.29
# Running iteration 23
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 40.67
# Running iteration 24
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 44.67
# Running iteration 25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 45.50
# Running iteration 26
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 48.77
# Running iteration 27
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.59
# Running iteration 28
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.20
# Running iteration 29
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 40.19
# Running iteration 30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 46.66
# Running iteration 31
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 46.37
# Running iteration 32
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 42.54
# Running iteration 33
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 42.95
# Running iteration 34
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.32
# Running iteration 35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 41.58
# Running iteration 36
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.82
# Running iteration 37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 41.51
# Running iteration 38
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.46
# Running iteration 39
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 46.04
# Running iteration 40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.74
# Running iteration 41
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.83
# Running iteration 42
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.45
# Running iteration 43
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.36
# Running iteration 44
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.57
# Running iteration 45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.79
# Running iteration 46
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 40.91
# Running iteration 47
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 42.73
# Running iteration 48
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.47
# Running iteration 49
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.69
# Running iteration 50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.57
# List length: 50
# Mean: 64.43
# Standard Deviation: 68.08

# %% [markdown]
# The mean of mean squared error after 50 iterations of 50 epoch/iterations on normalized data is 59.60. This value is slightly bigger than Step A's value (56.91) by 2.69. This indicates that the normalization did not improve the overall performance compared to Step A
#
# The standard deviation of the mean of mean squared error list on normalized data is 71.72. This value is much higher compared to the standard deviation on Step A (21.59) by 50.13. This indicates greater variability in the MSE value across iterations when using normalized data.

# %% [markdown]
# ## **C. Increate the number of epochs (5 marks)**
#
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
# Rebuild model
model = build_model()

# Create MSE list
mse_list_norm_c = []

# Repeat 50 times
for i in range(50):
    print(f"Running iteration {i+1}")
    X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3)
    model.fit(X_train, y_train, validation_split=0.3, epochs=100, verbose=0)
    y_pred = model.predict(X_test)
    loss = mean_squared_error(y_test, y_pred)
    mse_list_norm_c.append(loss)
    print(f"Loss: {loss:.2f}")

# List length
print(f"List length: {len(mse_list_norm_c)}")

# Print the mean and standard deviation of the MSE list
print(f"Mean: {sum(mse_list_norm_c)/len(mse_list_norm_c):.2f}")
print(f"Standard Deviation: {np.std(mse_list_norm_c):.2f}")
# Out:
# Running iteration 1
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Loss: 277.42
# Running iteration 2
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 124.90
# Running iteration 3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 61.51
# Running iteration 4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 47.82
# Running iteration 5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 37.57
# Running iteration 6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 35.30
# Running iteration 7
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 36.38
# Running iteration 8
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 43.15
# Running iteration 9
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 45.19
# Running iteration 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 39.77
# Running iteration 11
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.23
# Running iteration 12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.39
# Running iteration 13
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 39.44
# Running iteration 14
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 37.10
# Running iteration 15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.97
# Running iteration 16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 35.17
# Running iteration 17
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 35.40
# Running iteration 18
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 37.74
# Running iteration 19
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.00
# Running iteration 20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 31.74
# Running iteration 21
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 28.85
# Running iteration 22
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.21
# Running iteration 23
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.12
# Running iteration 24
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 35.90
# Running iteration 25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.91
# Running iteration 26
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 33.26
# Running iteration 27
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.27
# Running iteration 28
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 35.63
# Running iteration 29
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.06
# Running iteration 30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 33.68
# Running iteration 31
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 36.52
# Running iteration 32
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 27.70
# Running iteration 33
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.09
# Running iteration 34
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 33.56
# Running iteration 35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 28.33
# Running iteration 36
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 33.24
# Running iteration 37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.16
# Running iteration 38
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 31.52
# Running iteration 39
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.04
# Running iteration 40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 26.82
# Running iteration 41
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.10
# Running iteration 42
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.75
# Running iteration 43
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.13
# Running iteration 44
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.61
# Running iteration 45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.28
# Running iteration 46
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 33.58
# Running iteration 47
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 31.55
# Running iteration 48
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 31.93
# Running iteration 49
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.84
# Running iteration 50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.44
# List length: 50
# Mean: 41.19
# Standard Deviation: 36.50

# %% [markdown]
# The mean of mean squared error after 50 iterations of 100 epoch/iterations on normalized data is 47.42. This value is noticeably less than Step B's value (59.60) by 12.8. The reduction in the mean MSE indicates that extending the training from 50 to 100 epochs allowed the model to further minimize the error.
#
# The standard deviation of the mean of mean squared error list on normalized data at 100 epochs/iterations is 22.31. This value is much less compared to the standard deviation on Step B (71.72) by 49.41. The reduction in standard deviation indicates that the model's performance across iterations became more consistent when trained for a longer period.

# %% [markdown]
# ## **D. Increase the number of hidden layers (5 marks)**
#
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
# Build new model
def build_nn_model():
    model = Sequential()
    # Three hidden layers with 10 neurons and relu activation function
    model.add(Dense(10, activation='relu', input_shape=(8, )))
    model.add(Dense(10, activation='relu'))
    model.add(Dense(10, activation='relu'))
    # Output layer with 1 neuron and linear activation function
    model.add(Dense(1, activation='linear'))
    # Define the optimizer
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# %%
# Initialize the new model
model = build_nn_model()

# Create MSE list
mse_list_norm_d = []

# Repeat 50 times
for i in range(50):
    print(f"Running iteration {i+1}")
    X_train, X_test, y_train, y_test = train_test_split(X_norm, y, test_size=0.3)
    model.fit(X_train, y_train, validation_split=0.3, epochs=50, verbose=0)
    y_pred = model.predict(X_test)
    loss = mean_squared_error(y_test, y_pred)
    mse_list_norm_d.append(loss)
    print(f"Loss: {loss:.2f}")

# List length
print(f"List length: {len(mse_list_norm_d)}")

# Print the mean and standard deviation of the MSE list
print(f"Mean: {sum(mse_list_norm_d)/len(mse_list_norm_d):.2f}")
print(f"Standard Deviation: {np.std(mse_list_norm_d):.2f}")
# Out:
# Running iteration 1
# d:\Coding\ibm-ai-engineering\.venv\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Loss: 168.92
# Running iteration 2
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 102.90
# Running iteration 3
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 71.29
# Running iteration 4
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 58.12
# Running iteration 5
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 57.86
# Running iteration 6
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 40.27
# Running iteration 7
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 36.38
# Running iteration 8
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 39.17
# Running iteration 9
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 40.37
# Running iteration 10
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 38.40
# Running iteration 11
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 36.92
# Running iteration 12
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.48
# Running iteration 13
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 34.06
# Running iteration 14
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 31.67
# Running iteration 15
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.73
# Running iteration 16
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 27.19
# Running iteration 17
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 32.77
# Running iteration 18
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 26.81
# Running iteration 19
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 31.11
# Running iteration 20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Loss: 31.71
# Running iteration 21
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 30.25
# Running iteration 22
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.38
# Running iteration 23
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 26.08
# Running iteration 24
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 28.97
# Running iteration 25
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.70
# Running iteration 26
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.53
# Running iteration 27
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 29.12
# Running iteration 28
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 25.36
# Running iteration 29
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.26
# Running iteration 30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.43
# Running iteration 31
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.62
# Running iteration 32
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 27.88
# Running iteration 33
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 22.60
# Running iteration 34
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.11
# Running iteration 35
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 26.33
# Running iteration 36
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 21.83
# Running iteration 37
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.33
# Running iteration 38
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.38
# Running iteration 39
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 21.22
# Running iteration 40
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.99
# Running iteration 41
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.72
# Running iteration 42
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 20.95
# Running iteration 43
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 22.57
# Running iteration 44
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.70
# Running iteration 45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 20.85
# Running iteration 46
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.30
# Running iteration 47
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 22.97
# Running iteration 48
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 24.84
# Running iteration 49
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 20.86
# Running iteration 50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Loss: 23.18
# List length: 50
# Mean: 34.17
# Standard Deviation: 23.92

# %% [markdown]
# The mean of mean squared error after 50 iterations of 50 epoch/iterations on normalized data with a 3 hidden layers model is 34.17. This value is considerably less than Step B's value (59.60) by 25.8. The reduction in the mean MSE indicates that the increase of hidden layers in the model allows it to capture more complex patterns in data than the simpler model used in Step B.
#
# The standard deviation of the mean of mean squared error list on normalized data at 50 epochs/iterations with a 3 hidden layers model is 23.18. This value is much less compared to the standard deviation on Step B (71.72) by 48.54. The reduction in standard deviation indicates that the model's performance across iterations became much more consistent when the model is more complex.
